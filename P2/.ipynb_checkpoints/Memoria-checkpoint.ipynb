# %% [markdown]
# # Memoria Práctica 2

# %% [markdown]
# ## Apartado1

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
import time


datasets = ["example1.data","example2.data","example3.data","example4.data","wdbc.data"]
vecinos = [1,3,5,7,9,11]
n_particiones = 5
for k in vecinos:
    print("#############################################################################################################")
    print("########################################  K= ",k,"#############################################################")
    print("#############################################################################################################")
    for i in range(len(datasets)):
        start_time_train=0
        start_time_test=0
        dataset = Datos(datasets[i])

        particiones = ValidacionSimple(n_particiones,0.5,dataset).creaParticiones(dataset.datos)   
        errores = np.empty(n_particiones)
        for j in range(n_particiones):
            datosTrain = dataset.extraeDatos(particiones[j].indicesTrain)
            datosTest = dataset.extraeDatos(particiones[j].indicesTest)
            cKNN =  ClasificadorVecinosProximos()
            aux = time.time()
            cKNN.entrenamiento(datosTrain,dataset.nominalAtributos,dataset.diccionarios)
            start_time_train = start_time_train + time.time() - aux

            aux2 = time.time()
            res = cKNN.clasifica(datosTest[:,0:-1],dataset.nominalAtributos,dataset.diccionarios,False,k)
            start_time_test = start_time_test + time.time() - aux2

            error = Clasificador.error(datosTest,res)
            errores[j] = error
        print("---Tiempo de entrenamiento del modelo",datasets[i],"con",k,"vecinos:",start_time_train," segundos ---")
        print("---Tiempo de clasificacion del modelo",datasets[i],"con",k,"vecinos:",start_time_test," segundos ---")
        print("Tasa de error:",np.mean(errores))
# Out:
# #############################################################################################################
# ########################################  K=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 1 vecinos: 0.0008881092071533203  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con 1 vecinos: 5.574480295181274  segundos ---
# Tasa de error: 0.18391959798994978
# ---Tiempo de entrenamiento del modelo example2.data con 1 vecinos: 0.0009086132049560547  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con 1 vecinos: 5.442800521850586  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 1 vecinos: 0.0010330677032470703  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con 1 vecinos: 5.2376697063446045  segundos ---
# Tasa de error: 0.06130653266331658
# ---Tiempo de entrenamiento del modelo example4.data con 1 vecinos: 0.0007746219635009766  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con 1 vecinos: 0.32935404777526855  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con 1 vecinos: 0.0017404556274414062  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con 1 vecinos: 12.221571207046509  segundos ---
# Tasa de error: 0.057746478873239436
# #############################################################################################################
# ########################################  K=  3 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 3 vecinos: 0.0008039474487304688  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con 3 vecinos: 5.826350688934326  segundos ---
# Tasa de error: 0.17688442211055277
# ---Tiempo de entrenamiento del modelo example2.data con 3 vecinos: 0.0008423328399658203  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con 3 vecinos: 5.6070616245269775  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 3 vecinos: 0.0008382797241210938  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con 3 vecinos: 5.570664644241333  segundos ---
# Tasa de error: 0.06834170854271357
# ---Tiempo de entrenamiento del modelo example4.data con 3 vecinos: 0.0009055137634277344  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con 3 vecinos: 0.3914523124694824  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con 3 vecinos: 0.0014951229095458984  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con 3 vecinos: 11.377147912979126  segundos ---
# Tasa de error: 0.04859154929577464
# #############################################################################################################
# ########################################  K=  5 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 5 vecinos: 0.0009999275207519531  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con 5 vecinos: 8.075383186340332  segundos ---
# Tasa de error: 0.16984924623115577
# ---Tiempo de entrenamiento del modelo example2.data con 5 vecinos: 0.00091552734375  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con 5 vecinos: 6.119215488433838  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 5 vecinos: 0.0008625984191894531  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con 5 vecinos: 6.04111647605896  segundos ---
# Tasa de error: 0.07738693467336683
# ---Tiempo de entrenamiento del modelo example4.data con 5 vecinos: 0.0008144378662109375  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con 5 vecinos: 0.4580810070037842  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con 5 vecinos: 0.0017385482788085938  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con 5 vecinos: 12.319941997528076  segundos ---
# Tasa de error: 0.05563380281690141
# #############################################################################################################
# ########################################  K=  7 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 7 vecinos: 0.0010101795196533203  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con 7 vecinos: 7.4621422290802  segundos ---
# Tasa de error: 0.15175879396984926
# ---Tiempo de entrenamiento del modelo example2.data con 7 vecinos: 0.001005411148071289  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con 7 vecinos: 6.854405879974365  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 7 vecinos: 0.000965118408203125  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con 7 vecinos: 7.647516250610352  segundos ---
# Tasa de error: 0.06331658291457286
# ---Tiempo de entrenamiento del modelo example4.data con 7 vecinos: 0.0008828639984130859  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con 7 vecinos: 0.5648298263549805  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con 7 vecinos: 0.0017008781433105469  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con 7 vecinos: 15.155194997787476  segundos ---
# Tasa de error: 0.059859154929577475
# #############################################################################################################
# ########################################  K=  9 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 9 vecinos: 0.0008933544158935547  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con 9 vecinos: 6.000309705734253  segundos ---
# Tasa de error: 0.17386934673366833
# ---Tiempo de entrenamiento del modelo example2.data con 9 vecinos: 0.0008771419525146484  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con 9 vecinos: 6.631232261657715  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 9 vecinos: 0.0009386539459228516  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con 9 vecinos: 6.631371736526489  segundos ---
# Tasa de error: 0.0814070351758794
# ---Tiempo de entrenamiento del modelo example4.data con 9 vecinos: 0.0008652210235595703  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con 9 vecinos: 0.5262222290039062  segundos ---
# Tasa de error: 0.004081632653061224
# ---Tiempo de entrenamiento del modelo wdbc.data con 9 vecinos: 0.001562356948852539  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con 9 vecinos: 12.726937770843506  segundos ---
# Tasa de error: 0.07042253521126761
# #############################################################################################################
# ########################################  K=  11 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 11 vecinos: 0.0010418891906738281  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con 11 vecinos: 7.009289503097534  segundos ---
# Tasa de error: 0.15879396984924624
# ---Tiempo de entrenamiento del modelo example2.data con 11 vecinos: 0.0009746551513671875  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con 11 vecinos: 6.8325583934783936  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 11 vecinos: 0.0010128021240234375  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con 11 vecinos: 6.952131271362305  segundos ---
# Tasa de error: 0.07638190954773869
# ---Tiempo de entrenamiento del modelo example4.data con 11 vecinos: 0.0005981922149658203  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con 11 vecinos: 0.36959075927734375  segundos ---
# Tasa de error: 0.13061224489795917
# ---Tiempo de entrenamiento del modelo wdbc.data con 11 vecinos: 0.0014538764953613281  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con 11 vecinos: 12.803133249282837  segundos ---
# Tasa de error: 0.056338028169014086

# %%
# from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
import time


datasets = ["example1.data","example2.data","example3.data","example4.data","wdbc.data"]
vecinos = [1,3,5,7,9,11]
n_particiones = 5
for k in vecinos:
    print("#############################################################################################################")
    print("########################################  K= ",k,"#############################################################")
    print("#############################################################################################################")
    for i in range(len(datasets)):
        start_time_train=0
        start_time_test=0
        dataset = Datos(datasets[i])

        particiones = ValidacionSimple(n_particiones,0.5,dataset).creaParticiones(dataset.datos)   
        errores = np.empty(n_particiones)
        for j in range(n_particiones):
            datosTrain = dataset.extraeDatos(particiones[j].indicesTrain)
            datosTest = dataset.extraeDatos(particiones[j].indicesTest)
            cKNN =  ClasificadorVecinosProximos()
            aux = time.time()
            cKNN.entrenamiento(datosTrain,dataset.nominalAtributos,dataset.diccionarios,False)
            start_time_train = start_time_train + time.time() - aux

            aux2 = time.time()
            res = cKNN.clasifica(datosTest[:,0:-1],dataset.nominalAtributos,dataset.diccionarios,False,k,False)
            start_time_test = start_time_test + time.time() - aux2

            error = Clasificador.error(datosTest,res)
            errores[j] = error
        print("---Tiempo de entrenamiento del modelo",datasets[i],"con",k,"vecinos:",start_time_train," segundos ---")
        print("---Tiempo de clasificacion del modelo",datasets[i],"con",k,"vecinos:",start_time_test," segundos ---")
        print("Tasa de error:",np.mean(errores))
# Out:
# #############################################################################################################
# ########################################  K=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 1 vecinos: 7.557868957519531e-05  segundos ---
# ---Tiempo de clasificacion de la particion example1.data con 1 vecinos: 4.70957350730896  segundos ---
# Tasa de error: 0.16683417085427138
# ---Tiempo de entrenamiento del modelo example2.data con 1 vecinos: 0.00010251998901367188  segundos ---
# ---Tiempo de clasificacion de la particion example2.data con 1 vecinos: 5.153411388397217  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 1 vecinos: 9.107589721679688e-05  segundos ---
# ---Tiempo de clasificacion de la particion example3.data con 1 vecinos: 5.341871500015259  segundos ---
# Tasa de error: 0.031155778894472363
# ---Tiempo de entrenamiento del modelo example4.data con 1 vecinos: 8.7738037109375e-05  segundos ---
# ---Tiempo de clasificacion de la particion example4.data con 1 vecinos: 0.3583669662475586  segundos ---
# Tasa de error: 0.1306122448979592
# ---Tiempo de entrenamiento del modelo wdbc.data con 1 vecinos: 0.0001418590545654297  segundos ---
# ---Tiempo de clasificacion de la particion wdbc.data con 1 vecinos: 9.545573949813843  segundos ---
# Tasa de error: 0.08591549295774648
# #############################################################################################################
# ########################################  K=  3 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 3 vecinos: 8.463859558105469e-05  segundos ---
# ---Tiempo de clasificacion de la particion example1.data con 3 vecinos: 4.674912214279175  segundos ---
# Tasa de error: 0.16683417085427138
# ---Tiempo de entrenamiento del modelo example2.data con 3 vecinos: 8.845329284667969e-05  segundos ---
# ---Tiempo de clasificacion de la particion example2.data con 3 vecinos: 5.633108854293823  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 3 vecinos: 6.508827209472656e-05  segundos ---
# ---Tiempo de clasificacion de la particion example3.data con 3 vecinos: 5.271925926208496  segundos ---
# Tasa de error: 0.04221105527638191
# ---Tiempo de entrenamiento del modelo example4.data con 3 vecinos: 0.00011086463928222656  segundos ---
# ---Tiempo de clasificacion de la particion example4.data con 3 vecinos: 0.41512298583984375  segundos ---
# Tasa de error: 0.163265306122449
# ---Tiempo de entrenamiento del modelo wdbc.data con 3 vecinos: 0.00015997886657714844  segundos ---
# ---Tiempo de clasificacion de la particion wdbc.data con 3 vecinos: 10.605501174926758  segundos ---
# Tasa de error: 0.07535211267605633
# #############################################################################################################
# ########################################  K=  5 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 5 vecinos: 7.82012939453125e-05  segundos ---
# ---Tiempo de clasificacion de la particion example1.data con 5 vecinos: 4.846814155578613  segundos ---
# Tasa de error: 0.16180904522613065
# ---Tiempo de entrenamiento del modelo example2.data con 5 vecinos: 6.961822509765625e-05  segundos ---
# ---Tiempo de clasificacion de la particion example2.data con 5 vecinos: 4.793681859970093  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 5 vecinos: 8.249282836914062e-05  segundos ---
# ---Tiempo de clasificacion de la particion example3.data con 5 vecinos: 5.258407115936279  segundos ---
# Tasa de error: 0.053266331658291456
# ---Tiempo de entrenamiento del modelo example4.data con 5 vecinos: 5.841255187988281e-05  segundos ---
# ---Tiempo de clasificacion de la particion example4.data con 5 vecinos: 0.3301658630371094  segundos ---
# Tasa de error: 0.2857142857142857
# ---Tiempo de entrenamiento del modelo wdbc.data con 5 vecinos: 0.0001461505889892578  segundos ---
# ---Tiempo de clasificacion de la particion wdbc.data con 5 vecinos: 9.457672595977783  segundos ---
# Tasa de error: 0.08380281690140845
# #############################################################################################################
# ########################################  K=  7 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 7 vecinos: 7.510185241699219e-05  segundos ---
# ---Tiempo de clasificacion de la particion example1.data con 7 vecinos: 4.591216325759888  segundos ---
# Tasa de error: 0.1708542713567839
# ---Tiempo de entrenamiento del modelo example2.data con 7 vecinos: 0.00010204315185546875  segundos ---
# ---Tiempo de clasificacion de la particion example2.data con 7 vecinos: 4.678651571273804  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 7 vecinos: 7.915496826171875e-05  segundos ---
# ---Tiempo de clasificacion de la particion example3.data con 7 vecinos: 4.953269958496094  segundos ---
# Tasa de error: 0.0542713567839196
# ---Tiempo de entrenamiento del modelo example4.data con 7 vecinos: 7.605552673339844e-05  segundos ---
# ---Tiempo de clasificacion de la particion example4.data con 7 vecinos: 0.3698446750640869  segundos ---
# Tasa de error: 0.346938775510204
# ---Tiempo de entrenamiento del modelo wdbc.data con 7 vecinos: 0.0001423358917236328  segundos ---
# ---Tiempo de clasificacion de la particion wdbc.data con 7 vecinos: 9.622735977172852  segundos ---
# Tasa de error: 0.07464788732394366
# #############################################################################################################
# ########################################  K=  9 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 9 vecinos: 7.62939453125e-05  segundos ---
# ---Tiempo de clasificacion de la particion example1.data con 9 vecinos: 5.169953107833862  segundos ---
# Tasa de error: 0.1678391959798995
# ---Tiempo de entrenamiento del modelo example2.data con 9 vecinos: 8.487701416015625e-05  segundos ---
# ---Tiempo de clasificacion de la particion example2.data con 9 vecinos: 5.120595932006836  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 9 vecinos: 6.437301635742188e-05  segundos ---
# ---Tiempo de clasificacion de la particion example3.data con 9 vecinos: 5.3621556758880615  segundos ---
# Tasa de error: 0.05728643216080402
# ---Tiempo de entrenamiento del modelo example4.data con 9 vecinos: 7.62939453125e-05  segundos ---
# ---Tiempo de clasificacion de la particion example4.data con 9 vecinos: 0.3652036190032959  segundos ---
# Tasa de error: 0.3551020408163265
# ---Tiempo de entrenamiento del modelo wdbc.data con 9 vecinos: 0.00015807151794433594  segundos ---
# ---Tiempo de clasificacion de la particion wdbc.data con 9 vecinos: 10.151752710342407  segundos ---
# Tasa de error: 0.08661971830985915
# #############################################################################################################
# ########################################  K=  11 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con 11 vecinos: 7.557868957519531e-05  segundos ---
# ---Tiempo de clasificacion de la particion example1.data con 11 vecinos: 5.458388566970825  segundos ---
# Tasa de error: 0.16683417085427138
# ---Tiempo de entrenamiento del modelo example2.data con 11 vecinos: 6.532669067382812e-05  segundos ---
# ---Tiempo de clasificacion de la particion example2.data con 11 vecinos: 4.903650760650635  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo example3.data con 11 vecinos: 6.67572021484375e-05  segundos ---
# ---Tiempo de clasificacion de la particion example3.data con 11 vecinos: 4.894185543060303  segundos ---
# Tasa de error: 0.07236180904522613
# ---Tiempo de entrenamiento del modelo example4.data con 11 vecinos: 6.198883056640625e-05  segundos ---
# ---Tiempo de clasificacion de la particion example4.data con 11 vecinos: 0.3247084617614746  segundos ---
# Tasa de error: 0.3795918367346939
# ---Tiempo de entrenamiento del modelo wdbc.data con 11 vecinos: 0.00014019012451171875  segundos ---
# ---Tiempo de clasificacion de la particion wdbc.data con 11 vecinos: 10.027719497680664  segundos ---
# Tasa de error: 0.08943661971830985

# %% [markdown]
# ### Conclusiones:

# %% [markdown]
# Como podemos ver a la salida de los dos códigos anteriores, el aumento del número de vecinos a observar no mejora significativamente nuestra tasa de error, sin embargo,lo que si que produce beneficia a la correcta clasificación en nuestros conjuntos de datos es la Normalización en los archivos example4.data y wdbc.data esto puede deberse a que los atributos de estos archivos están representados en distintos órdenes de magnitud. También cabe mencionar el reducido coste de entrenamiento incluso en el caso en el que normalizamos los datos que es mucho menor que el coste computacional de clasificación. Por ell el clasificador de vecinos próximos será adecuado cuando dispongamos de un tiempo de etrenamiento limitado y no nos preocupe en demasía que tarde en clasificar un dato. A continuación mostramos gráficamente las fronteras que se corresponden bastante a las tasas de error

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
from plotModel import plotModel 
import matplotlib.pyplot as plt 

datasets = ["example1.data","example2.data","example3.data","example4.data"]
n_particiones = 1
for i in range(len(datasets)):
    dataset = Datos(datasets[i])

    particiones = ValidacionSimple(n_particiones,0.3,dataset).creaParticiones(dataset.datos)   
    errores = np.empty(n_particiones)
    for j in range(n_particiones):
        datosTrain = dataset.extraeDatos(particiones[j].indicesTrain)
        datosTest = dataset.extraeDatos(particiones[j].indicesTest)
        cKNN =  ClasificadorVecinosProximos()
        cKNN.entrenamiento(datosTrain,dataset.nominalAtributos,dataset.diccionarios)
        plt.figure()
        plotModel(dataset.datos[particiones[j].indicesTrain,0],dataset.datos[particiones[j].indicesTrain,1],
                dataset.datos[particiones[j].indicesTrain,-1] !=0, cKNN,"Frontera",dataset.diccionarios)
        plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],  
         dataset.datos[dataset.datos[:,-1]==0,1],'ro')
        plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],  
         dataset.datos[dataset.datos[:,-1]==1,1],'bo')
        plt.show()

# %% [markdown]
# ## Apartado 2

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
import time


datasets = ["example1.data","example2.data","example3.data","example4.data","wdbc.data"]
nus = [0.2,1,10,50]
nepocas = [4,50, 100,200]
n_particiones = 5
for nu in nus:
    for nepoca in nepocas:
        print("#############################################################################################################")
        print("########################################  nu= ",nu,"#############################################################")
        print("#############################################################################################################")
        for i in range(len(datasets)):
            start_time_train=0
            start_time_test=0
            dataset = Datos(datasets[i])

            particiones = ValidacionSimple(n_particiones,0.5,dataset).creaParticiones(dataset.datos)   
            errores = np.empty(n_particiones)
            for j in range(n_particiones):
                datosTrain = dataset.extraeDatos(particiones[j].indicesTrain)
                datosTest = dataset.extraeDatos(particiones[j].indicesTest)
                cRL =  ClasificadorRegresionLineal()
                aux = time.time()
                cRL.entrenamiento(datosTrain,dataset.nominalAtributos,dataset.diccionarios,nu,nepoca)
                start_time_train = start_time_train + time.time() - aux

                aux2 = time.time()
                res = cRL.clasifica(datosTest[:,0:-1],dataset.nominalAtributos,dataset.diccionarios)
                start_time_test = start_time_test + time.time() - aux2

                error = Clasificador.error(datosTest,res)
                errores[j] = error
            print("---Tiempo de entrenamiento del modelo",datasets[i],"con nu =",nu,"y nepocas =",nepoca,":",start_time_train," segundos ---")
            print("---Tiempo de clasificacion del modelo",datasets[i],"con nu =",nu,"y nepocas =",nepoca,":",start_time_test," segundos ---")
            print("Tasa de error:",np.mean(errores))
# Out:
# #############################################################################################################
# ########################################  nu=  0.2 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 0.2 y nepocas = 4 : 0.04968833923339844  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 0.2 y nepocas = 4 : 0.009831666946411133  segundos ---
# Tasa de error: 0.5306532663316583
# ---Tiempo de entrenamiento del modelo example2.data con nu = 0.2 y nepocas = 4 : 0.04790830612182617  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 0.2 y nepocas = 4 : 0.016236543655395508  segundos ---
# Tasa de error: 0.45929648241206034
# ---Tiempo de entrenamiento del modelo example3.data con nu = 0.2 y nepocas = 4 : 0.03873109817504883  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 0.2 y nepocas = 4 : 0.006442546844482422  segundos ---
# Tasa de error: 0.4773869346733668
# ---Tiempo de entrenamiento del modelo example4.data con nu = 0.2 y nepocas = 4 : 0.012794256210327148  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 0.2 y nepocas = 4 : 0.0027604103088378906  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 0.2 y nepocas = 4 : 0.0870215892791748  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 0.2 y nepocas = 4 : 0.01717686653137207  segundos ---
# Tasa de error: 0.04225352112676056
# #############################################################################################################
# ########################################  nu=  0.2 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 0.2 y nepocas = 50 : 0.9234282970428467  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 0.2 y nepocas = 50 : 0.008435964584350586  segundos ---
# Tasa de error: 0.5035175879396985
# ---Tiempo de entrenamiento del modelo example2.data con nu = 0.2 y nepocas = 50 : 0.5626363754272461  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 0.2 y nepocas = 50 : 0.007635354995727539  segundos ---
# Tasa de error: 0.5095477386934674
# ---Tiempo de entrenamiento del modelo example3.data con nu = 0.2 y nepocas = 50 : 0.6947500705718994  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 0.2 y nepocas = 50 : 0.010455131530761719  segundos ---
# Tasa de error: 0.5025125628140703
# ---Tiempo de entrenamiento del modelo example4.data con nu = 0.2 y nepocas = 50 : 0.19784760475158691  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 0.2 y nepocas = 50 : 0.0034227371215820312  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 0.2 y nepocas = 50 : 1.0452535152435303  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 0.2 y nepocas = 50 : 0.015458345413208008  segundos ---
# Tasa de error: 0.03591549295774647
# #############################################################################################################
# ########################################  nu=  0.2 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 0.2 y nepocas = 100 : 1.1252236366271973  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 0.2 y nepocas = 100 : 0.010140180587768555  segundos ---
# Tasa de error: 0.5125628140703518
# ---Tiempo de entrenamiento del modelo example2.data con nu = 0.2 y nepocas = 100 : 1.288618803024292  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 0.2 y nepocas = 100 : 0.00964808464050293  segundos ---
# Tasa de error: 0.5095477386934674
# ---Tiempo de entrenamiento del modelo example3.data con nu = 0.2 y nepocas = 100 : 1.1282436847686768  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 0.2 y nepocas = 100 : 0.008242607116699219  segundos ---
# Tasa de error: 0.5427135678391959
# ---Tiempo de entrenamiento del modelo example4.data con nu = 0.2 y nepocas = 100 : 0.3026602268218994  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 0.2 y nepocas = 100 : 0.0029969215393066406  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 0.2 y nepocas = 100 : 1.9606802463531494  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 0.2 y nepocas = 100 : 0.01694798469543457  segundos ---
# Tasa de error: 0.060563380281690136
# #############################################################################################################
# ########################################  nu=  0.2 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 0.2 y nepocas = 200 : 2.488737106323242  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 0.2 y nepocas = 200 : 0.007151365280151367  segundos ---
# Tasa de error: 0.43618090452261316
# ---Tiempo de entrenamiento del modelo example2.data con nu = 0.2 y nepocas = 200 : 2.309540033340454  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 0.2 y nepocas = 200 : 0.008057594299316406  segundos ---
# Tasa de error: 0.6
# ---Tiempo de entrenamiento del modelo example3.data con nu = 0.2 y nepocas = 200 : 2.2491376399993896  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 0.2 y nepocas = 200 : 0.009153604507446289  segundos ---
# Tasa de error: 0.585929648241206
# ---Tiempo de entrenamiento del modelo example4.data con nu = 0.2 y nepocas = 200 : 0.6067233085632324  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 0.2 y nepocas = 200 : 0.0028069019317626953  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 0.2 y nepocas = 200 : 3.8486440181732178  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 0.2 y nepocas = 200 : 0.016600847244262695  segundos ---
# Tasa de error: 0.03591549295774647
# #############################################################################################################
# ########################################  nu=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 1 y nepocas = 4 : 0.04826474189758301  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 1 y nepocas = 4 : 0.009758949279785156  segundos ---
# Tasa de error: 0.5035175879396985
# ---Tiempo de entrenamiento del modelo example2.data con nu = 1 y nepocas = 4 : 0.05489921569824219  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 1 y nepocas = 4 : 0.008018732070922852  segundos ---
# Tasa de error: 0.4180904522613065
# ---Tiempo de entrenamiento del modelo example3.data con nu = 1 y nepocas = 4 : 0.042685747146606445  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 1 y nepocas = 4 : 0.006768703460693359  segundos ---
# Tasa de error: 0.507537688442211
# ---Tiempo de entrenamiento del modelo example4.data con nu = 1 y nepocas = 4 : 0.02002739906311035  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 1 y nepocas = 4 : 0.0031516551971435547  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 1 y nepocas = 4 : 0.07762861251831055  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 1 y nepocas = 4 : 0.013876676559448242  segundos ---
# Tasa de error: 0.04647887323943661
# #############################################################################################################
# ########################################  nu=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 1 y nepocas = 50 : 0.5730607509613037  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 1 y nepocas = 50 : 0.008267402648925781  segundos ---
# Tasa de error: 0.43819095477386927
# ---Tiempo de entrenamiento del modelo example2.data con nu = 1 y nepocas = 50 : 0.5172395706176758  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 1 y nepocas = 50 : 0.0069506168365478516  segundos ---
# Tasa de error: 0.5015075376884421
# ---Tiempo de entrenamiento del modelo example3.data con nu = 1 y nepocas = 50 : 0.5643172264099121  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 1 y nepocas = 50 : 0.00668644905090332  segundos ---
# Tasa de error: 0.42512562814070354
# ---Tiempo de entrenamiento del modelo example4.data con nu = 1 y nepocas = 50 : 0.12636876106262207  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 1 y nepocas = 50 : 0.0024378299713134766  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 1 y nepocas = 50 : 0.9888453483581543  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 1 y nepocas = 50 : 0.014623165130615234  segundos ---
# Tasa de error: 0.05
# #############################################################################################################
# ########################################  nu=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 1 y nepocas = 100 : 1.0032577514648438  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 1 y nepocas = 100 : 0.0067596435546875  segundos ---
# Tasa de error: 0.4452261306532663
# ---Tiempo de entrenamiento del modelo example2.data con nu = 1 y nepocas = 100 : 1.0999212265014648  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 1 y nepocas = 100 : 0.0076007843017578125  segundos ---
# Tasa de error: 0.3939698492462312
# ---Tiempo de entrenamiento del modelo example3.data con nu = 1 y nepocas = 100 : 1.1697092056274414  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 1 y nepocas = 100 : 0.008717775344848633  segundos ---
# Tasa de error: 0.4522613065326634
# ---Tiempo de entrenamiento del modelo example4.data con nu = 1 y nepocas = 100 : 0.2728919982910156  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 1 y nepocas = 100 : 0.003093242645263672  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 1 y nepocas = 100 : 1.997330904006958  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 1 y nepocas = 100 : 0.013061761856079102  segundos ---
# Tasa de error: 0.0528169014084507
# #############################################################################################################
# ########################################  nu=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 1 y nepocas = 200 : 2.4315874576568604  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 1 y nepocas = 200 : 0.008901596069335938  segundos ---
# Tasa de error: 0.4190954773869347
# ---Tiempo de entrenamiento del modelo example2.data con nu = 1 y nepocas = 200 : 2.115863084793091  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 1 y nepocas = 200 : 0.007508754730224609  segundos ---
# Tasa de error: 0.45929648241206034
# ---Tiempo de entrenamiento del modelo example3.data con nu = 1 y nepocas = 200 : 2.1842241287231445  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 1 y nepocas = 200 : 0.009300708770751953  segundos ---
# Tasa de error: 0.41608040201005025
# ---Tiempo de entrenamiento del modelo example4.data con nu = 1 y nepocas = 200 : 0.7265756130218506  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 1 y nepocas = 200 : 0.0033655166625976562  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 1 y nepocas = 200 : 4.011634826660156  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 1 y nepocas = 200 : 0.013006210327148438  segundos ---
# Tasa de error: 0.04507042253521126
# #############################################################################################################
# ########################################  nu=  10 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 10 y nepocas = 4 : 0.04505801200866699  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 10 y nepocas = 4 : 0.006610870361328125  segundos ---
# Tasa de error: 0.5175879396984925
# ---Tiempo de entrenamiento del modelo example2.data con nu = 10 y nepocas = 4 : 0.054941654205322266  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 10 y nepocas = 4 : 0.008716821670532227  segundos ---
# Tasa de error: 0.392964824120603
# ---Tiempo de entrenamiento del modelo example3.data con nu = 10 y nepocas = 4 : 0.04831266403198242  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 10 y nepocas = 4 : 0.0077245235443115234  segundos ---
# Tasa de error: 0.514572864321608
# ---Tiempo de entrenamiento del modelo example4.data con nu = 10 y nepocas = 4 : 0.015599250793457031  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 10 y nepocas = 4 : 0.0022988319396972656  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 10 y nepocas = 4 : 0.07221436500549316  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 10 y nepocas = 4 : 0.01402425765991211  segundos ---
# Tasa de error: 0.05070422535211268
# #############################################################################################################
# ########################################  nu=  10 #############################################################
# #############################################################################################################
# /home/jovyan/Clasificador.py:290: RuntimeWarning: overflow encountered in exp
#   return 1./(1+ np.exp(-sum(self.omega*x)))
# ---Tiempo de entrenamiento del modelo example1.data con nu = 10 y nepocas = 50 : 0.5205080509185791  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 10 y nepocas = 50 : 0.007725954055786133  segundos ---
# Tasa de error: 0.493467336683417
# ---Tiempo de entrenamiento del modelo example2.data con nu = 10 y nepocas = 50 : 0.5434134006500244  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 10 y nepocas = 50 : 0.008285760879516602  segundos ---
# Tasa de error: 0.23819095477386934
# ---Tiempo de entrenamiento del modelo example3.data con nu = 10 y nepocas = 50 : 0.7522296905517578  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 10 y nepocas = 50 : 0.008118152618408203  segundos ---
# Tasa de error: 0.48542713567839185
# ---Tiempo de entrenamiento del modelo example4.data con nu = 10 y nepocas = 50 : 0.15394234657287598  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 10 y nepocas = 50 : 0.0026433467864990234  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 10 y nepocas = 50 : 1.1458203792572021  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 10 y nepocas = 50 : 0.017844438552856445  segundos ---
# Tasa de error: 0.04859154929577465
# #############################################################################################################
# ########################################  nu=  10 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 10 y nepocas = 100 : 1.2311689853668213  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 10 y nepocas = 100 : 0.008062601089477539  segundos ---
# Tasa de error: 0.521608040201005
# ---Tiempo de entrenamiento del modelo example2.data con nu = 10 y nepocas = 100 : 1.4256079196929932  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 10 y nepocas = 100 : 0.009488821029663086  segundos ---
# Tasa de error: 0.4301507537688442
# ---Tiempo de entrenamiento del modelo example3.data con nu = 10 y nepocas = 100 : 1.3291592597961426  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 10 y nepocas = 100 : 0.009667158126831055  segundos ---
# Tasa de error: 0.4874371859296482
# ---Tiempo de entrenamiento del modelo example4.data con nu = 10 y nepocas = 100 : 0.4038374423980713  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 10 y nepocas = 100 : 0.003641843795776367  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 10 y nepocas = 100 : 2.527867078781128  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 10 y nepocas = 100 : 0.019372224807739258  segundos ---
# Tasa de error: 0.057746478873239436
# #############################################################################################################
# ########################################  nu=  10 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 10 y nepocas = 200 : 2.3551580905914307  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 10 y nepocas = 200 : 0.008599281311035156  segundos ---
# Tasa de error: 0.4783919597989949
# ---Tiempo de entrenamiento del modelo example2.data con nu = 10 y nepocas = 200 : 2.6926939487457275  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 10 y nepocas = 200 : 0.008686542510986328  segundos ---
# Tasa de error: 0.507537688442211
# ---Tiempo de entrenamiento del modelo example3.data con nu = 10 y nepocas = 200 : 2.4596664905548096  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 10 y nepocas = 200 : 0.00830841064453125  segundos ---
# Tasa de error: 0.521608040201005
# ---Tiempo de entrenamiento del modelo example4.data con nu = 10 y nepocas = 200 : 0.7134809494018555  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 10 y nepocas = 200 : 0.003283977508544922  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 10 y nepocas = 200 : 4.939659833908081  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 10 y nepocas = 200 : 0.016812801361083984  segundos ---
# Tasa de error: 0.04295774647887324
# #############################################################################################################
# ########################################  nu=  50 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 50 y nepocas = 4 : 0.05151724815368652  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 50 y nepocas = 4 : 0.007912158966064453  segundos ---
# Tasa de error: 0.4341708542713568
# ---Tiempo de entrenamiento del modelo example2.data con nu = 50 y nepocas = 4 : 0.053179264068603516  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 50 y nepocas = 4 : 0.009088754653930664  segundos ---
# Tasa de error: 0.5035175879396985
# ---Tiempo de entrenamiento del modelo example3.data con nu = 50 y nepocas = 4 : 0.06454062461853027  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 50 y nepocas = 4 : 0.012552261352539062  segundos ---
# Tasa de error: 0.4864321608040201
# ---Tiempo de entrenamiento del modelo example4.data con nu = 50 y nepocas = 4 : 0.01736736297607422  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 50 y nepocas = 4 : 0.0033125877380371094  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 50 y nepocas = 4 : 0.10811686515808105  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 50 y nepocas = 4 : 0.021096467971801758  segundos ---
# Tasa de error: 0.0528169014084507
# #############################################################################################################
# ########################################  nu=  50 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 50 y nepocas = 50 : 0.5421657562255859  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 50 y nepocas = 50 : 0.007393360137939453  segundos ---
# Tasa de error: 0.4663316582914573
# ---Tiempo de entrenamiento del modelo example2.data con nu = 50 y nepocas = 50 : 0.6162865161895752  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 50 y nepocas = 50 : 0.008772134780883789  segundos ---
# Tasa de error: 0.3979899497487437
# ---Tiempo de entrenamiento del modelo example3.data con nu = 50 y nepocas = 50 : 0.5707473754882812  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 50 y nepocas = 50 : 0.008331060409545898  segundos ---
# Tasa de error: 0.43618090452261293
# ---Tiempo de entrenamiento del modelo example4.data con nu = 50 y nepocas = 50 : 0.15679335594177246  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 50 y nepocas = 50 : 0.002849578857421875  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 50 y nepocas = 50 : 1.2456932067871094  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 50 y nepocas = 50 : 0.018939733505249023  segundos ---
# Tasa de error: 0.059154929577464786
# #############################################################################################################
# ########################################  nu=  50 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 50 y nepocas = 100 : 1.188096523284912  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 50 y nepocas = 100 : 0.006903886795043945  segundos ---
# Tasa de error: 0.5095477386934674
# ---Tiempo de entrenamiento del modelo example2.data con nu = 50 y nepocas = 100 : 1.0726280212402344  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 50 y nepocas = 100 : 0.0072634220123291016  segundos ---
# Tasa de error: 0.39899497487437185
# ---Tiempo de entrenamiento del modelo example3.data con nu = 50 y nepocas = 100 : 1.0669136047363281  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 50 y nepocas = 100 : 0.006788015365600586  segundos ---
# Tasa de error: 0.48542713567839196
# ---Tiempo de entrenamiento del modelo example4.data con nu = 50 y nepocas = 100 : 0.34706616401672363  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 50 y nepocas = 100 : 0.0034570693969726562  segundos ---
# Tasa de error: 0.008163265306122448
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 50 y nepocas = 100 : 2.7732136249542236  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 50 y nepocas = 100 : 0.018447160720825195  segundos ---
# Tasa de error: 0.0528169014084507
# #############################################################################################################
# ########################################  nu=  50 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 50 y nepocas = 200 : 2.268827438354492  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 50 y nepocas = 200 : 0.007460594177246094  segundos ---
# Tasa de error: 0.4753768844221106
# ---Tiempo de entrenamiento del modelo example2.data con nu = 50 y nepocas = 200 : 2.03225040435791  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 50 y nepocas = 200 : 0.006665706634521484  segundos ---
# Tasa de error: 0.45929648241206034
# ---Tiempo de entrenamiento del modelo example3.data con nu = 50 y nepocas = 200 : 2.338202714920044  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 50 y nepocas = 200 : 0.009068965911865234  segundos ---
# Tasa de error: 0.45929648241206034
# ---Tiempo de entrenamiento del modelo example4.data con nu = 50 y nepocas = 200 : 0.7523958683013916  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 50 y nepocas = 200 : 0.0029239654541015625  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 50 y nepocas = 200 : 5.41115927696228  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 50 y nepocas = 200 : 0.019982337951660156  segundos ---
# Tasa de error: 0.06126760563380281

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
import time


datasets = ["example1.data","example2.data","example3.data","example4.data","wdbc.data"]
nus = [0.2,1,10,50]
nepocas = [4,50, 100]
n_particiones = 5
for nu in nus:
    for nepoca in nepocas:
        print("#############################################################################################################")
        print("########################################  nu= ",nu,"#############################################################")
        print("#############################################################################################################")
        for i in range(len(datasets)):
            start_time_train=0
            start_time_test=0
            dataset = Datos(datasets[i])

            particiones = ValidacionSimple(n_particiones,0.5,dataset).creaParticiones(dataset.datos,False)   
            errores = np.empty(n_particiones)
            for j in range(n_particiones):
                datosTrain = dataset.extraeDatos(particiones[j].indicesTrain)
                datosTest = dataset.extraeDatos(particiones[j].indicesTest)
                cKNN =  ClasificadorRegresionLineal()
                aux = time.time()
                cKNN.entrenamiento(datosTrain,dataset.nominalAtributos,dataset.diccionarios,nu,nepoca,False)
                start_time_train = start_time_train + time.time() - aux

                aux2 = time.time()
                res = cKNN.clasifica(datosTest[:,0:-1],dataset.nominalAtributos,dataset.diccionarios)
                start_time_test = start_time_test + time.time() - aux

                error = Clasificador.error(datosTest,res)
                errores[j] = error
            print("---Tiempo de entrenamiento del modelo",datasets[i],"con nu =",nu,"y nepocas =",nepoca,":",start_time_train," segundos ---")
            print("---Tiempo de clasificacion del modelo",datasets[i],"con nu =",nu,"y nepocas =",nepoca,":",start_time_test," segundos ---")
            print("Tasa de error:",np.mean(errores))
# Out:
# #############################################################################################################
# ########################################  nu=  0.2 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 0.2 y nepocas = 4 : 0.058469295501708984  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 0.2 y nepocas = 4 : 0.06715869903564453  segundos ---
# Tasa de error: 0.4683417085427136
# ---Tiempo de entrenamiento del modelo example2.data con nu = 0.2 y nepocas = 4 : 0.05803275108337402  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 0.2 y nepocas = 4 : 0.06804227828979492  segundos ---
# Tasa de error: 0.4673366834170854
# ---Tiempo de entrenamiento del modelo example3.data con nu = 0.2 y nepocas = 4 : 0.06161975860595703  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 0.2 y nepocas = 4 : 0.07140398025512695  segundos ---
# Tasa de error: 0.4623115577889448
# ---Tiempo de entrenamiento del modelo example4.data con nu = 0.2 y nepocas = 4 : 0.016033411026000977  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 0.2 y nepocas = 4 : 0.019070148468017578  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 0.2 y nepocas = 4 : 0.09120512008666992  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 0.2 y nepocas = 4 : 0.10739827156066895  segundos ---
# Tasa de error: 0.8908450704225352
# #############################################################################################################
# ########################################  nu=  0.2 #############################################################
# #############################################################################################################
# /home/jovyan/Clasificador.py:290: RuntimeWarning: overflow encountered in exp
#   return 1./(1+ np.exp(-sum(self.omega*x)))
# ---Tiempo de entrenamiento del modelo example1.data con nu = 0.2 y nepocas = 50 : 0.549231767654419  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 0.2 y nepocas = 50 : 0.5566549301147461  segundos ---
# Tasa de error: 0.44522613065326644
# ---Tiempo de entrenamiento del modelo example2.data con nu = 0.2 y nepocas = 50 : 0.5439720153808594  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 0.2 y nepocas = 50 : 0.5516743659973145  segundos ---
# Tasa de error: 0.4673366834170854
# ---Tiempo de entrenamiento del modelo example3.data con nu = 0.2 y nepocas = 50 : 0.5204613208770752  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 0.2 y nepocas = 50 : 0.5281884670257568  segundos ---
# Tasa de error: 0.4623115577889448
# ---Tiempo de entrenamiento del modelo example4.data con nu = 0.2 y nepocas = 50 : 0.1607375144958496  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 0.2 y nepocas = 50 : 0.16348624229431152  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 0.2 y nepocas = 50 : 1.467064380645752  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 0.2 y nepocas = 50 : 1.4857032299041748  segundos ---
# Tasa de error: 0.8915492957746478
# #############################################################################################################
# ########################################  nu=  0.2 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 0.2 y nepocas = 100 : 1.1093878746032715  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 0.2 y nepocas = 100 : 1.1180810928344727  segundos ---
# Tasa de error: 0.44522613065326644
# ---Tiempo de entrenamiento del modelo example2.data con nu = 0.2 y nepocas = 100 : 1.3248193264007568  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 0.2 y nepocas = 100 : 1.3327019214630127  segundos ---
# Tasa de error: 0.4673366834170854
# ---Tiempo de entrenamiento del modelo example3.data con nu = 0.2 y nepocas = 100 : 1.159496784210205  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 0.2 y nepocas = 100 : 1.1683146953582764  segundos ---
# Tasa de error: 0.4623115577889448
# ---Tiempo de entrenamiento del modelo example4.data con nu = 0.2 y nepocas = 100 : 0.3606734275817871  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 0.2 y nepocas = 100 : 0.3642306327819824  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 0.2 y nepocas = 100 : 2.569749593734741  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 0.2 y nepocas = 100 : 2.5912206172943115  segundos ---
# Tasa de error: 0.8732394366197184
# #############################################################################################################
# ########################################  nu=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 1 y nepocas = 4 : 0.04289436340332031  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 1 y nepocas = 4 : 0.05129647254943848  segundos ---
# Tasa de error: 0.5005025125628141
# ---Tiempo de entrenamiento del modelo example2.data con nu = 1 y nepocas = 4 : 0.03651928901672363  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 1 y nepocas = 4 : 0.04281139373779297  segundos ---
# Tasa de error: 0.4653266331658291
# ---Tiempo de entrenamiento del modelo example3.data con nu = 1 y nepocas = 4 : 0.03994154930114746  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 1 y nepocas = 4 : 0.0460972785949707  segundos ---
# Tasa de error: 0.4743718592964824
# ---Tiempo de entrenamiento del modelo example4.data con nu = 1 y nepocas = 4 : 0.009323835372924805  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 1 y nepocas = 4 : 0.01130366325378418  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 1 y nepocas = 4 : 0.0841376781463623  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 1 y nepocas = 4 : 0.09981417655944824  segundos ---
# Tasa de error: 0.8908450704225352
# #############################################################################################################
# ########################################  nu=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 1 y nepocas = 50 : 0.5892736911773682  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 1 y nepocas = 50 : 0.598541259765625  segundos ---
# Tasa de error: 0.4894472361809045
# ---Tiempo de entrenamiento del modelo example2.data con nu = 1 y nepocas = 50 : 0.6954865455627441  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 1 y nepocas = 50 : 0.7049410343170166  segundos ---
# Tasa de error: 0.4653266331658291
# ---Tiempo de entrenamiento del modelo example3.data con nu = 1 y nepocas = 50 : 0.5601794719696045  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 1 y nepocas = 50 : 0.566786527633667  segundos ---
# Tasa de error: 0.43517587939698493
# ---Tiempo de entrenamiento del modelo example4.data con nu = 1 y nepocas = 50 : 0.13085055351257324  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 1 y nepocas = 50 : 0.1334686279296875  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 1 y nepocas = 50 : 1.3677635192871094  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 1 y nepocas = 50 : 1.3888723850250244  segundos ---
# Tasa de error: 0.8922535211267606
# #############################################################################################################
# ########################################  nu=  1 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 1 y nepocas = 100 : 1.391709327697754  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 1 y nepocas = 100 : 1.4009833335876465  segundos ---
# Tasa de error: 0.4894472361809045
# ---Tiempo de entrenamiento del modelo example2.data con nu = 1 y nepocas = 100 : 1.205824851989746  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 1 y nepocas = 100 : 1.2144930362701416  segundos ---
# Tasa de error: 0.4653266331658291
# ---Tiempo de entrenamiento del modelo example3.data con nu = 1 y nepocas = 100 : 1.1007049083709717  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 1 y nepocas = 100 : 1.1080248355865479  segundos ---
# Tasa de error: 0.507537688442211
# ---Tiempo de entrenamiento del modelo example4.data con nu = 1 y nepocas = 100 : 0.3341975212097168  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 1 y nepocas = 100 : 0.3370175361633301  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 1 y nepocas = 100 : 2.6059587001800537  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 1 y nepocas = 100 : 2.6237454414367676  segundos ---
# Tasa de error: 0.871830985915493
# #############################################################################################################
# ########################################  nu=  10 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 10 y nepocas = 4 : 0.057573795318603516  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 10 y nepocas = 4 : 0.06745195388793945  segundos ---
# Tasa de error: 0.5608040201005026
# ---Tiempo de entrenamiento del modelo example2.data con nu = 10 y nepocas = 4 : 0.04822945594787598  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 10 y nepocas = 4 : 0.05594587326049805  segundos ---
# Tasa de error: 0.49447236180904525
# ---Tiempo de entrenamiento del modelo example3.data con nu = 10 y nepocas = 4 : 0.05645442008972168  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 10 y nepocas = 4 : 0.06581735610961914  segundos ---
# Tasa de error: 0.4984924623115578
# ---Tiempo de entrenamiento del modelo example4.data con nu = 10 y nepocas = 4 : 0.019954204559326172  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 10 y nepocas = 4 : 0.023159265518188477  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 10 y nepocas = 4 : 0.09678530693054199  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 10 y nepocas = 4 : 0.11825346946716309  segundos ---
# Tasa de error: 0.8908450704225352
# #############################################################################################################
# ########################################  nu=  10 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 10 y nepocas = 50 : 0.5667269229888916  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 10 y nepocas = 50 : 0.5756735801696777  segundos ---
# Tasa de error: 0.4522613065326633
# ---Tiempo de entrenamiento del modelo example2.data con nu = 10 y nepocas = 50 : 0.5219089984893799  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 10 y nepocas = 50 : 0.5292458534240723  segundos ---
# Tasa de error: 0.49447236180904525
# ---Tiempo de entrenamiento del modelo example3.data con nu = 10 y nepocas = 50 : 0.6114964485168457  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 10 y nepocas = 50 : 0.6201541423797607  segundos ---
# Tasa de error: 0.4442211055276382
# ---Tiempo de entrenamiento del modelo example4.data con nu = 10 y nepocas = 50 : 0.16936874389648438  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 10 y nepocas = 50 : 0.17258977890014648  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 10 y nepocas = 50 : 1.2876617908477783  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 10 y nepocas = 50 : 1.305640459060669  segundos ---
# Tasa de error: 0.8922535211267606
# #############################################################################################################
# ########################################  nu=  10 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 10 y nepocas = 100 : 1.0345046520233154  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 10 y nepocas = 100 : 1.0420236587524414  segundos ---
# Tasa de error: 0.5135678391959799
# ---Tiempo de entrenamiento del modelo example2.data con nu = 10 y nepocas = 100 : 1.0831353664398193  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 10 y nepocas = 100 : 1.0911548137664795  segundos ---
# Tasa de error: 0.49447236180904525
# ---Tiempo de entrenamiento del modelo example3.data con nu = 10 y nepocas = 100 : 1.249631404876709  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 10 y nepocas = 100 : 1.2585182189941406  segundos ---
# Tasa de error: 0.5015075376884421
# ---Tiempo de entrenamiento del modelo example4.data con nu = 10 y nepocas = 100 : 0.35630273818969727  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 10 y nepocas = 100 : 0.35982751846313477  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 10 y nepocas = 100 : 2.3595776557922363  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 10 y nepocas = 100 : 2.3750879764556885  segundos ---
# Tasa de error: 0.873943661971831
# #############################################################################################################
# ########################################  nu=  50 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 50 y nepocas = 4 : 0.03876662254333496  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 50 y nepocas = 4 : 0.045191287994384766  segundos ---
# Tasa de error: 0.4683417085427136
# ---Tiempo de entrenamiento del modelo example2.data con nu = 50 y nepocas = 4 : 0.0672304630279541  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 50 y nepocas = 4 : 0.0779266357421875  segundos ---
# Tasa de error: 0.49447236180904525
# ---Tiempo de entrenamiento del modelo example3.data con nu = 50 y nepocas = 4 : 0.05808305740356445  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 50 y nepocas = 4 : 0.0668337345123291  segundos ---
# Tasa de error: 0.49648241206030147
# ---Tiempo de entrenamiento del modelo example4.data con nu = 50 y nepocas = 4 : 0.009198665618896484  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 50 y nepocas = 4 : 0.0110931396484375  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 50 y nepocas = 4 : 0.09519457817077637  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 50 y nepocas = 4 : 0.11161351203918457  segundos ---
# Tasa de error: 0.8908450704225352
# #############################################################################################################
# ########################################  nu=  50 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 50 y nepocas = 50 : 0.6315603256225586  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 50 y nepocas = 50 : 0.6385736465454102  segundos ---
# Tasa de error: 0.507537688442211
# ---Tiempo de entrenamiento del modelo example2.data con nu = 50 y nepocas = 50 : 0.5514247417449951  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 50 y nepocas = 50 : 0.5590965747833252  segundos ---
# Tasa de error: 0.49447236180904525
# ---Tiempo de entrenamiento del modelo example3.data con nu = 50 y nepocas = 50 : 0.7925267219543457  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 50 y nepocas = 50 : 0.80055832862854  segundos ---
# Tasa de error: 0.47537688442211057
# ---Tiempo de entrenamiento del modelo example4.data con nu = 50 y nepocas = 50 : 0.14447951316833496  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 50 y nepocas = 50 : 0.14743900299072266  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 50 y nepocas = 50 : 1.1526403427124023  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 50 y nepocas = 50 : 1.1702499389648438  segundos ---
# Tasa de error: 0.8922535211267606
# #############################################################################################################
# ########################################  nu=  50 #############################################################
# #############################################################################################################
# ---Tiempo de entrenamiento del modelo example1.data con nu = 50 y nepocas = 100 : 1.0803735256195068  segundos ---
# ---Tiempo de clasificacion del modelo example1.data con nu = 50 y nepocas = 100 : 1.0888960361480713  segundos ---
# Tasa de error: 0.4522613065326634
# ---Tiempo de entrenamiento del modelo example2.data con nu = 50 y nepocas = 100 : 1.445873498916626  segundos ---
# ---Tiempo de clasificacion del modelo example2.data con nu = 50 y nepocas = 100 : 1.4532849788665771  segundos ---
# Tasa de error: 0.49447236180904525
# ---Tiempo de entrenamiento del modelo example3.data con nu = 50 y nepocas = 100 : 1.1900103092193604  segundos ---
# ---Tiempo de clasificacion del modelo example3.data con nu = 50 y nepocas = 100 : 1.1973598003387451  segundos ---
# Tasa de error: 0.4663316582914573
# ---Tiempo de entrenamiento del modelo example4.data con nu = 50 y nepocas = 100 : 0.2752034664154053  segundos ---
# ---Tiempo de clasificacion del modelo example4.data con nu = 50 y nepocas = 100 : 0.2779378890991211  segundos ---
# Tasa de error: 0.0
# ---Tiempo de entrenamiento del modelo wdbc.data con nu = 50 y nepocas = 100 : 2.709019184112549  segundos ---
# ---Tiempo de clasificacion del modelo wdbc.data con nu = 50 y nepocas = 100 : 2.7263333797454834  segundos ---
# Tasa de error: 0.873943661971831

# %% [markdown]
# ### Conclusiones:

# %% [markdown]
# Vemos que la regresión lineal es muy mala para los conjuntos de de datos example1.data,example2.data y example3.data lo cual nos lleva a pensa que usar un clasificador lineal no es adecuado para estos problemas, por otro lado en el archivo example4.data obtenemos una tasa de error de 0 y en wdbc.data varía bastante la tasa de error respecto a normalizar o no normalizar lo cual nos lleva a pensar que los datos estan representados en distintas escalas de magnitud. Para terminar, es relevante mencionar que en estos conjuntos de datos la regresión logística converge relativamente rápido y que es un tipo de clasificador con un alto coste de entrenamiento y bajo coste de clasificación de ejemplos. A continuación mostramos gráficamente las fronteras que se corresponden bastante a las tasas de error

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
from plotModel import plotModel 
import matplotlib.pyplot as plt 

datasets = ["example1.data","example2.data","example3.data","example4.data"]
n_particiones = 1
for i in range(len(datasets)):
    dataset = Datos(datasets[i])

    particiones = ValidacionSimple(n_particiones,0.1,dataset).creaParticiones(dataset.datos)   
    errores = np.empty(n_particiones)
    for j in range(n_particiones):
        datosTrain = dataset.extraeDatos(particiones[j].indicesTrain)
        datosTest = dataset.extraeDatos(particiones[j].indicesTest)
        cRL =  ClasificadorRegresionLineal()
        cRL.entrenamiento(datosTrain,dataset.nominalAtributos,dataset.diccionarios,1,100)
        res = cRL.clasifica(datosTest[:,:-1],dataset.nominalAtributos,dataset.diccionarios)

        error = Clasificador.error(datosTest,res)
        errores[j] = error
        plt.figure()
        plotModel(dataset.datos[particiones[j].indicesTrain,0],dataset.datos[particiones[j].indicesTrain,1],
                dataset.datos[particiones[j].indicesTrain,-1] !=0, cRL,"Frontera",dataset.diccionarios)
        plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],  
         dataset.datos[dataset.datos[:,-1]==0,1],'ro')
        plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],  
         dataset.datos[dataset.datos[:,-1]==1,1],'bo')
        plt.show()
    print(np.mean(errores))
# Out:
# 0.4986072423398329
# 0.25348189415041783
# 0.4596100278551532
# 0.0

# %% [markdown]
# ## Apartado 3

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
from sklearn.neighbors import KNeighborsClassifier
from plotModel import plotModel 
import matplotlib.pyplot as plt 
datasets = ["example1.data","example2.data","example3.data","example4.data"]
n_particiones = 1
for i in range(len(datasets)):
    dataset = Datos(datasets[i])

    particiones = ValidacionSimple(n_particiones,0.3,dataset).creaParticiones(dataset.datos)   
    errores = np.empty(n_particiones)
    for j in range(n_particiones):
        datosTrain = dataset.extraeDatos(particiones[j].indicesTrain)
        datosTest = dataset.extraeDatos(particiones[j].indicesTest)

        neigh = KNeighborsClassifier(n_neighbors=5, weights='uniform', p=2) #pesos uniformes, norma 2, 5 vecinos
        neigh.fit(datosTrain[:,:-1],datosTrain[:,-1])
        res = neigh.predict(datosTest[:,:-1])
        error = Clasificador.error(datosTest,res)
    plt.figure()
    plotModel(dataset.datos[particiones[j].indicesTrain,0],dataset.datos[particiones[j].indicesTrain,1],
        dataset.datos[particiones[j].indicesTrain,-1] !=0, neigh,"Frontera",dataset.diccionarios)
    plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],  
     dataset.datos[dataset.datos[:,-1]==0,1],'ro')
    plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],  
     dataset.datos[dataset.datos[:,-1]==1,1],'bo')
    plt.show()
    print("Error de scikit:"),
    print(error)
# Out:
# Error de scikit:
# 0.13978494623655913
# Error de scikit:
# 0.0
# Error de scikit:
# 0.043010752688172046
# Error de scikit:
# 0.37681159420289856

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
from sklearn.linear_model import LogisticRegression

datasets = ["example1.data","example2.data","example3.data","example4.data"]
n_particiones = 1
for i in range(len(datasets)):
    dataset = Datos(datasets[i])

    particiones = ValidacionSimple(n_particiones,0.3,dataset).creaParticiones(dataset.datos)   

    datosTrain = dataset.extraeDatos(particiones[0].indicesTrain)
    datosTest = dataset.extraeDatos(particiones[0].indicesTest)
    cRLs = LogisticRegression(solver='lbfgs', max_iter=500) #solver por defecto, se puede usar sag para resulatdos mas parecidos
    cRLs.fit(datosTrain[:,:-1],datosTrain[:,-1])
    res = cRLs.predict(datosTest[:,:-1])
    error = Clasificador.error(datosTest,res)
    plt.figure()
    plotModel(dataset.datos[particiones[j].indicesTrain,0],dataset.datos[particiones[j].indicesTrain,1],
        dataset.datos[particiones[j].indicesTrain,-1] !=0, cRLs,"Frontera",dataset.diccionarios)
    plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],  
     dataset.datos[dataset.datos[:,-1]==0,1],'ro')
    plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],  
     dataset.datos[dataset.datos[:,-1]==1,1],'bo')
    plt.show()
    print("Error de scikit:"),
    print(error)
# Out:
# /home/rober/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# /home/rober/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Error de scikit:
# 0.5412186379928315
# Error de scikit:
# 0.5232974910394266
# /home/rober/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Error de scikit:
# 0.5340501792114696
# Error de scikit:
# 0.0

# %%
from Datos import *
from Clasificador import *
from EstrategiaParticionado import *
from sklearn.linear_model import SGDClassifier

datasets = ["example1.data","example2.data","example3.data","example4.data"]
n_particiones = 1
for i in range(len(datasets)):
    dataset = Datos(datasets[i])

    particiones = ValidacionSimple(n_particiones,0.1,dataset).creaParticiones(dataset.datos)   
    datosTrain = dataset.extraeDatos(particiones[0].indicesTrain)
    datosTest = dataset.extraeDatos(particiones[0].indicesTest)
    sgd = SGDClassifier(loss='log', max_iter=500, learning_rate='optimal') #regresion logistica, con 500 iteraciones. No hay equivalente para nuestra tasa de aprendizaje
    sgd.fit(datosTrain[:,:-1],datosTrain[:,-1])
    res = sgd.predict(datosTest[:,:-1])
    error = Clasificador.error(datosTest,res)
    plt.figure()
    plotModel(dataset.datos[particiones[j].indicesTrain,0],dataset.datos[particiones[j].indicesTrain,1],
        dataset.datos[particiones[j].indicesTrain,-1] !=0, sgd,"Frontera",dataset.diccionarios)
    plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],  
     dataset.datos[dataset.datos[:,-1]==0,1],'ro')
    plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],  
     dataset.datos[dataset.datos[:,-1]==1,1],'bo')
    plt.show()
    print("Error de scikit:"),
    print(error)
# Out:
# Error de scikit:
# 0.5153203342618384
# Error de scikit:
# 0.5153203342618384
# Error de scikit:
# 0.520891364902507
# Error de scikit:
# 0.0
